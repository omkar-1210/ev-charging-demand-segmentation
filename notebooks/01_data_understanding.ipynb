# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\loneo\OneDrive\Documents\ev-charging-demand-segmentation\data\raw\EVChargingStationUsage.csv")
# Out:
# C:\Users\loneo\AppData\Local\Temp\ipykernel_27184\3935048766.py:1: DtypeWarning: Columns (0: User ID, 1: County, 2: Model Number) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\Users\loneo\OneDrive\Documents\ev-charging-demand-segmentation\data\raw\EVChargingStationUsage.csv")

# %%
data.head(3)
# Out:
#                  Station Name          MAC Address           Org Name  \
# 0  PALO ALTO CA / HAMILTON #1  000D:6F00:015A:9D76  City of Palo Alto
# 1  PALO ALTO CA / HAMILTON #1  000D:6F00:015A:9D76  City of Palo Alto
# 2  PALO ALTO CA / HAMILTON #1  000D:6F00:015A:9D76  City of Palo Alto
#
#         Start Date Start Time Zone         End Date End Time Zone  \
# 0  7/29/2011 20:17             PDT  7/29/2011 23:20           PDT
# 1   7/30/2011 0:00             PDT   7/30/2011 0:02           PDT
# 2   7/30/2011 8:16             PDT  7/30/2011 12:34           PDT
#
#   Transaction Date (Pacific Time) Total Duration (hh:mm:ss)  \
# 0                 7/29/2011 23:20                   3:03:32
# 1                  7/30/2011 0:02                   0:02:06
# 2                 7/30/2011 12:34                   4:17:32
#
#   Charging Time (hh:mm:ss)  ...   Longitude  Currency  Fee  \
# 0                  1:54:03  ... -122.160309       USD  0.0
# ...

# %%
print(data.shape)
print('\n')
print(data.columns)
print('\n')
print(data.dtypes)
print('\n')
print(data.isnull().sum())
print('\n')
print(data.duplicated().sum())
print('\n')
print(data['Station Name'].value_counts())
print('\n')
print(data.info())
print('\n')
print(data.describe())
print('\n')
# Out:
# (259415, 33)
#
#
# Index(['Station Name', 'MAC Address', 'Org Name', 'Start Date',
#        'Start Time Zone', 'End Date', 'End Time Zone',
#        'Transaction Date (Pacific Time)', 'Total Duration (hh:mm:ss)',
#        'Charging Time (hh:mm:ss)', 'Energy (kWh)', 'GHG Savings (kg)',
#        'Gasoline Savings (gallons)', 'Port Type', 'Port Number', 'Plug Type',
#        'EVSE ID', 'Address 1', 'City', 'State/Province', 'Postal Code',
#        'Country', 'Latitude', 'Longitude', 'Currency', 'Fee', 'Ended By',
#        'Plug In Event Id', 'Driver Postal Code', 'User ID', 'County',
#        'System S/N', 'Model Number'],
#       dtype='str')
#
#
# Station Name                           str
# MAC Address                            str
# Org Name                               str
# Start Date                             str
# Start Time Zone                        str
# End Date                               str
# End Time Zone                          str
# ...

# %%
data['Station Name'].nunique()
# Out:
# 47

# %%
print(data[['Start Date','End Date']].dtypes)

data['Start Date']=pd.to_datetime(data['Start Date'])
#data['End Date']=pd.to_datetime(data['End Date'])
# Out:
# Start Date    str
# End Date      str
# dtype: object

# %%
data['Start Date'].min()
# Out:
# Timestamp('2011-07-29 20:17:00')

# %%
data['Start Date'].max()
# Out:
# Timestamp('2020-12-31 18:19:00')

# %%
data['Start Date'].sort_values()[0:5]
# Out:
# 0   2011-07-29 20:17:00
# 1   2011-07-30 00:00:00
# 2   2011-07-30 08:16:00
# 3   2011-07-30 14:51:00
# 4   2011-07-30 18:51:00
# Name: Start Date, dtype: datetime64[us]

# %%
data[data['Station Name']=='PALO ALTO CA / HAMILTON #2']
# Out:
#                       Station Name          MAC Address            Org Name  \
# 10      PALO ALTO CA / HAMILTON #2  000D:6F00:009E:D39E  City of Palo Alto
# 12      PALO ALTO CA / HAMILTON #2  000D:6F00:009E:D39E  City of Palo Alto
# 14      PALO ALTO CA / HAMILTON #2  000D:6F00:009E:D39E  City of Palo Alto
# 17      PALO ALTO CA / HAMILTON #2  000D:6F00:009E:D39E  City of Palo Alto
# 19      PALO ALTO CA / HAMILTON #2  000D:6F00:009E:D39E  City of Palo Alto
# ...                            ...                  ...                 ...
# 257290  PALO ALTO CA / HAMILTON #2  0024:B100:0002:965D  City of Palo Alto
# 257294  PALO ALTO CA / HAMILTON #2  0024:B100:0002:965D  City of Palo Alto
# 257330  PALO ALTO CA / HAMILTON #2  0024:B100:0002:965D  City of Palo Alto
# 257332  PALO ALTO CA / HAMILTON #2  0024:B100:0002:965D  City of Palo Alto
# 257337  PALO ALTO CA / HAMILTON #2  0024:B100:0002:965D  City of Palo Alto
#
# ...
